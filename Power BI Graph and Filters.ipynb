# %%
ASSIGNEMNT - Power BI Graph and Filters

1.
What is Power BI used for in data analytics?



clip

2.
How can you create a bar graph in Power BI?



clip

3.
Explain the importance of filters in data visualization using Power BI.



clip

4.
What are the different types of graphs that can be created in Power BI?



clip

5.
How can you customize the appearance of graphs in Power BI reports?



clip

6.
What is the difference between a clustered column chart and a stacked column chart in Power BI?



clip

7.
How can you add dynamic filters to Power BI reports for interactive analysis?



clip

8.
Explain the process of creating a trend line in Power BI graphs.



clip

9.
What is the purpose of using slicers in Power BI dashboards?



clip

10.
How can you drill down into specific data points in a Power BI graph?



clip

11.
Explain the concept of cross-filtering in Power BI.



clip

12.
What are some best practices for choosing the right type of graph for data visualization in Power BI?

# %%
QUIZ   Power BI Graph and Filters

1.
What does Power BI use to create relationships between multiple data tables?
Joins
Relationships
Aggregations
Filters
clip

2.
Which Power BI graph type is best for comparing values across categories?
Pie chart
Line chart
Clustered column chart
Area chart
clip

3.
In Power BI, what type of filter can be used to make selections by clicking on individual data points within a visualization?
Slicer filter
Page filter
Cross-filter
Drill-through filter
clip

4.
Which DAX function in Power BI should be used to calculate the total sales for a specific product category?
CALCULATE
SUM
SUMX
AVERAGE
clip

5.
Which statement about Power BI report-level filters is correct?
They only affect one visual
They apply to individual pages
They apply to all visuals on a report page
They cannot be edited once set
clip

6.
Which statement regarding Power BI slicers is true?
Slicers are used to zoom in on visuals
A slicer selection applies to only one visual
Slicers allow interactive filtering across multiple visuals
Slicers can't be customized in Power BI
clip

7.
Which type of relationship is established between two tables in Power BI when there is no relationship detected between their columns?
Direct relationship
Indirect relationship
Cross-filtered relationship
Linked relationship
clip

8.
Which option allows you to control the order of values displayed along the axis in a Power BI bar chart?
Sort by Value
Sort by Name
Sort by Column
Sort Ascending
clip

9.
What is the purpose of a Power BI hierarchy?
To filter visuals based on multiple criteria
To group related data attributes
To drill down or up through levels of data
To change visual colors dynamically
clip

10.
Which Power BI tool should be used to create custom calculations and metrics for analysis?
Query Editor
Power Query
DAX
M Language
clip

11.
When creating a Power BI report, which step typically follows data importation and transformation?
Data Visualization
Data Analysis
Data Modeling
Data Sharing
clip

12.
Which statement correctly describes a measure in Power BI?
Measures are static and unchangeable
Measures are only used for text formatting
Measures are dynamic calculations
Measures can only be used in one visualization
